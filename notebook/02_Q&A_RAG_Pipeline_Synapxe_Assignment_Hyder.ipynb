# %% [markdown]
# # Problem Statement

# %% [markdown]
# - A local healthcare company published multiple articles containing healthcare facts,information, and tips. It wishes to create a conversational chatbot that can address readers’concerns in natural language using information from the trusted articles and in the healthcare context.
# - The conversational chatbot should answer readers' queries using only the information from the published articles. Where appropriate, it should adopt an empathetic and understanding
# tone.

# %% [markdown]
# # Solution

# %%
# !pip install openai langchain langchain-openai langchain_chroma ragas grandalf
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.23.6)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.1.16)
# Requirement already satisfied: langchain-openai in /usr/local/lib/python3.10/dist-packages (0.1.3)
# Requirement already satisfied: langchain_chroma in /usr/local/lib/python3.10/dist-packages (0.1.0)
# Requirement already satisfied: ragas in /usr/local/lib/python3.10/dist-packages (0.1.7)
# Requirement already satisfied: grandalf in /usr/local/lib/python3.10/dist-packages (0.8)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.32 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.0.34)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.42 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.46)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.51)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.3)
# Requirement already satisfied: tiktoken<1,>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-openai) (0.6.0)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain_chroma) (0.4.24)
# Requirement already satisfied: fastapi<1,>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from langchain_chroma) (0.110.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from ragas) (2.19.0)
# Requirement already satisfied: pysbd>=0.3.4 in /usr/local/lib/python3.10/dist-packages (from ragas) (0.3.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ragas) (1.6.0)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from ragas) (1.4.4)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from grandalf) (3.1.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.7.3)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.29.0)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (3.5.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.17.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.45b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.24.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.62.2)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (4.1.2)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.9.4)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (29.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (3.10.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi<1,>=0.95.2->langchain_chroma) (0.37.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2.0,>=0.1.42->langchain) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.5.2->langchain-openai) (2023.12.25)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (3.13.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (2.0.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (0.22.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (2.0.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (3.2.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.0->langchain_chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.0->langchain_chroma) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.0->langchain_chroma) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (7.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.45b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (67.7.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (2.2.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (12.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->ragas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->ragas) (2024.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (4.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (3.18.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.0->langchain_chroma) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.6.0)

# %%
import os

os.environ["OPENAI_API_KEY"] = ""

# %% [markdown]
# Retrieve PDF and HTML docs

# %%
import pandas as pd

docs_df = pd.read_pickle("/content/docs_13_pdf_htmls_df.pkl")

display(docs_df.head(10))
display(pd.DataFrame(docs_df["urls"].value_counts()))
# Out:
#                                                 text  \
# 0  SUPPORT\n\n1\n\nSupporting individuals with di...
# 1  What is positive social support?\n\nWhat is po...
# 2  Learn About Diabetes\n\nKnow When to Step Back...
# 3  Here are some key areas of diabetes management...
# 4  2. Be a good listener\n\n2. Be a good listener...
# 5  Here are some helpful questions you can ask wh...
# 6  • Would you like me to take you or accompany y...
# 7  4. Do it together\n\n4. Do it together\n\n• A ...
# 8  • For example, stop buying unhealthy snacks fo...
# 9  • Your role is not to be the food police but t...
#
#                                               source  \
# 0  12_pdf_57c95e67895840888240d7322f00117c?v=f00c...
# 1  12_pdf_57c95e67895840888240d7322f00117c?v=f00c...
# 2  12_pdf_57c95e67895840888240d7322f00117c?v=f00c...
# 3  12_pdf_57c95e67895840888240d7322f00117c?v=f00c...
# 4  12_pdf_57c95e67895840888240d7322f00117c?v=f00c...
# 5  12_pdf_57c95e67895840888240d7322f00117c?v=f00c...
# 6  12_pdf_57c95e67895840888240d7322f00117c?v=f00c...
# 7  12_pdf_57c95e67895840888240d7322f00117c?v=f00c...
# 8  12_pdf_57c95e67895840888240d7322f00117c?v=f00c...
# 9  12_pdf_57c95e67895840888240d7322f00117c?v=f00c...
#
#                                                 urls  \
# 0  https://ch-api.healthhub.sg/api/public/content...
# 1  https://ch-api.healthhub.sg/api/public/content...
# 2  https://ch-api.healthhub.sg/api/public/content...
# 3  https://ch-api.healthhub.sg/api/public/content...
# 4  https://ch-api.healthhub.sg/api/public/content...
# 5  https://ch-api.healthhub.sg/api/public/content...
# 6  https://ch-api.healthhub.sg/api/public/content...
# 7  https://ch-api.healthhub.sg/api/public/content...
# 8  https://ch-api.healthhub.sg/api/public/content...
# 9  https://ch-api.healthhub.sg/api/public/content...
#
#                                             metadata
# 0  {'source': 'https://ch-api.healthhub.sg/api/pu...
# 1  {'source': 'https://ch-api.healthhub.sg/api/pu...
# 2  {'source': 'https://ch-api.healthhub.sg/api/pu...
# 3  {'source': 'https://ch-api.healthhub.sg/api/pu...
# 4  {'source': 'https://ch-api.healthhub.sg/api/pu...
# 5  {'source': 'https://ch-api.healthhub.sg/api/pu...
# 6  {'source': 'https://ch-api.healthhub.sg/api/pu...
# 7  {'source': 'https://ch-api.healthhub.sg/api/pu...
# 8  {'source': 'https://ch-api.healthhub.sg/api/pu...
# 9  {'source': 'https://ch-api.healthhub.sg/api/pu...
#                                                     count
# urls
# https://ch-api.healthhub.sg/api/public/content/...    208
# https://www.ace-hta.gov.sg/docs/default-source/...    114
# https://ch-api.healthhub.sg/api/public/content/...     85
# https://ch-api.healthhub.sg/api/public/content/...     45
# https://ch-api.healthhub.sg/api/public/content/...     40
# https://www.ace-hta.gov.sg/docs/default-source/...     35
# https://www.ace-hta.gov.sg/docs/default-source/...     35
# https://www.healthxchange.sg/diabetes/living-we...     28
# https://www.healthhub.sg/a-z/diseases-and-condi...     20
# https://www.healthhub.sg/a-z/diseases-and-condi...     14
# https://ch-api.healthhub.sg/api/public/content/...     12
# https://www.healthhub.sg/a-z/diseases-and-condi...      9
# https://www.healthhub.sg/a-z/diseases-and-condi...      7

# %%
from langchain_core.documents.base import Document

docs = []

for index, row in docs_df.iterrows():
  page_content = row["text"]
  metadata = row["metadata"]

  doc = Document(page_content = page_content, metadata = metadata)
  docs.append(doc)

# %% [markdown]
# Create RAG pipeline using Chroma vector store and LangChain

# %%
# vectorstore.delete_collection() # delete collection from vectorstore

# %%
from langchain_chroma import Chroma
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_core.runnables import RunnableParallel
from langchain_openai import OpenAIEmbeddings
from langchain_openai import ChatOpenAI
from langchain.retrievers.multi_query import MultiQueryRetriever
from langchain.chains import create_history_aware_retriever, create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

llm = ChatOpenAI(model="gpt-3.5-turbo")

# setup multiquery retriever with chroma
vectordb = Chroma.from_documents(documents=docs, embedding=OpenAIEmbeddings(model = "text-embedding-ada-002"))
retriever = MultiQueryRetriever.from_llm(retriever = vectordb.as_retriever(), llm = llm)
# retriever = vectordb.as_retriever(search_kwargs = {"k": 1})

# contextualize the question
contextualize_q_system_prompt = """Given a chat history and the latest user question \
which might reference context in the chat history, formulate a standalone question \
which can be understood without the chat history. Do NOT answer the question, \
just reformulate it if needed and otherwise return it as is."""
contextualize_q_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", contextualize_q_system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ]
)
history_aware_retriever = create_history_aware_retriever(
    llm, retriever, contextualize_q_prompt
)

# question answer prompt
qa_system_prompt = """You are a compassionate and considerate healthcare assistant for question-answering tasks. \
If you don't know the answer, just say that you don't know in a sympathetic manner, and base your responses solely on the information derived from the context. \
Be empathetic, considerate and concise in your responses. \

context: {context}"""
qa_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", qa_system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ]
)
question_answer_chain = create_stuff_documents_chain(llm, qa_prompt)

rag_chain = create_retrieval_chain(history_aware_retriever, question_answer_chain)

# statefully manage chat history
store = {}

def get_session_history(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]

conversational_rag_chain = RunnableWithMessageHistory(
    rag_chain,
    get_session_history,
    input_messages_key="input",
    history_messages_key="chat_history",
    output_messages_key="answer",
)

conversational_rag_chain.get_graph().print_ascii()
# Out:
#                          +-----------------------------+
#                          | Parallel<chat_history>Input |
#                          +-----------------------------+
#                                 ***            ***
#                               **                  **
#                             **                      **
#             +------------------------+          +-------------+
#             | Lambda(_enter_history) |          | Passthrough |
#             +------------------------+          +-------------+
#                                 ***            ***
#                                    **        **
#                                      **    **
#                         +------------------------------+
#                         | Parallel<chat_history>Output |
#                         +------------------------------+
#                                         *
#                                         *
#                                         *
#                            +------------------------+
#                            | Parallel<context>Input |
#                            +------------------------+
#                                   **         ***
#                                 **              *
#                                *                 **
#                         +--------+          +-------------+
#                         | Branch |          | Passthrough |
#                         +--------+          +-------------+
#                                   **         ***
#                                     **      *
#                                       *   **
#                            +-------------------------+
#                            | Parallel<context>Output |
#                            +-------------------------+
#                                         *
#                                         *
#                                         *
#                             +-----------------------+
#                             | Parallel<answer>Input |
#                             +-----------------------+
#                               ***                   *****
#                            ***                           *****
#                          **                                   ****
#          +------------------------+                               ***
#          | Parallel<context>Input |                                 *
#          +------------------------+                                 *
#                **           **                                      *
#              **               **                                    *
#            **                   **                                  *
# +----------------+          +-------------+                         *
# | PromptTemplate |          | Passthrough |                         *
# +----------------+          +-------------+                         *
#                **           **                                      *
#                  **       **                                        *
#                    **   **                                          *
#          +-------------------------+                                *
#          | Parallel<context>Output |                                *
#          +-------------------------+                                *
#                       *                                             *
#                       *                                             *
#                       *                                             *
#            +--------------------+                                   *
#            | ChatPromptTemplate |                                   *
#            +--------------------+                                   *
#                       *                                             *
#                       *                                             *
#                       *                                             *
#                +------------+                                       *
#                | ChatOpenAI |                                       *
#                +------------+                                       *
#                       *                                             *
#                       *                                             *
#                       *                                             *
#              +-----------------+                             +-------------+
#              | StrOutputParser |                             | Passthrough |
#              +-----------------+                         ****+-------------+
#                               ***                    ****
#                                  ***            *****
#                                     **       ***
#                            +------------------------+
#                            | Parallel<answer>Output |
#                            +------------------------+

# %% [markdown]
# Run queries using RAG

# %%
queries = \
[
    "What is gestational diabetes and how is it diagnosed?",
    "What are some healthy eating tips for people with diabetes?",
    "How can my outpatient bill for diabetes be covered?",
    "How does insulin pump therapy mimic the function of the pancreas?",
    "What factors should be considered when determining appropriate exercises for a wheelchair user?",
    "What can excess internal fat lead to in terms of inflammation and damage of body cells?",
    "What is the suggested location for doing lunchtime exercises?",
    "What are the main medications used by patients with type 2 diabetes mellitus in Singapore?",
    "How can rotating injection sites prevent fat lump formation in insulin pump therapy?",
    "What is the purpose of an insulin reservoir in insulin pump therapy and how does it relate to rotating injection sites for proper absorption and to prevent swelling?"
]

question_list = []
source_list = []
context_list = []
answer_list = []

for query in queries:
  print(query)
  result = conversational_rag_chain.invoke({"input": query}, config={"configurable": {"session_id": "abc123"}},)

  ans = result["answer"]
  answer_list.append(ans)

  source_set = set([doc.metadata["source"] for doc in result["context"]])

  source_text = ""
  for source in source_set:
    source_text += source + "\n"

  ans = f"{ans}\n\nSource:\n{source_text}"
  print(ans)
  print()

  question_list.append(query)
  source_list.append(source_text)
  context_list.append([doc.page_content for doc in result["context"]])

eval_dict = \
 {
     "question": question_list,
     "source": source_list,
     "answer": answer_list,
     "contexts": context_list
 }

print(eval_dict)
# Out:
# What is gestational diabetes and how is it diagnosed?
# Gestational diabetes is a type of diabetes that develops during pregnancy. It is diagnosed through screening tests such as the 3-point OGTT (oral glucose tolerance test) using the criteria set by the International Association of Diabetes and Pregnancy Study Group (IADPSG), which includes measuring plasma glucose levels at fasting, 1-hour post-OGTT, and 2-hour post-OGTT. If these levels meet the criteria specified in Table 1, then gestational diabetes is diagnosed.
#
# Source:
# https://www.ace-hta.gov.sg/docs/default-source/acgs/gdm---an-update-on-screening-diagnosis-and-follow-up-(may-2018).pdf
#
#
# What are some healthy eating tips for people with diabetes?
# Healthy eating tips for people with diabetes include:
# 1. Eating a well-balanced diet with a variety of fruits, vegetables, whole grains, lean proteins, and healthy fats.
# 2. Monitoring carbohydrate intake and choosing complex carbohydrates over simple sugars.
# 3. Limiting saturated fats, trans fats, cholesterol, and sodium in the diet.
# 4. Eating regular meals and snacks to help maintain blood sugar levels.
# 5. Being mindful of portion sizes and calorie intake to support weight management.
# 6. Working with a healthcare provider or dietitian to create a personalized meal plan that fits individual dietary needs and diabetes management goals.
#
# Source:
# https://www.ace-hta.gov.sg/docs/default-source/default-library/managing-pre-diabetes-(updated-on-27-jul-2021)c2bfc77474154c2abf623156a4b93002.pdf
#
#
# How can my outpatient bill for diabetes be covered?
# Your outpatient bill for diabetes can be covered through various ways such as:
# 1. Government subsidies available at public specialist outpatient clinics (SOCs), polyclinics, and CHAS GPs.
# 2. Employee benefits or private medical insurance (PMI) that may help cover expenses.
# 3. Utilizing your MediSave account or Chronic Disease Management Programme (CDMP) for diabetes-related costs.
# 4. Any remaining balance can be covered through out-of-pocket payment after deducting subsidies, benefits, insurance, and MediSave contributions.
#
# Source:
# https://ch-api.healthhub.sg/api/public/content/57c95e67895840888240d7322f00117c?v=f00ca9b4&_gl=1*1tq2sup*_ga*MTk3Mjg0Mjc5Ni4xNzA3Nzg5OTUw
#
#
# How does insulin pump therapy mimic the function of the pancreas?
# Insulin pump therapy mimics the function of the pancreas by delivering both basal (continuous release over 24 hours) and rapid-acting insulin doses. This helps to regulate blood glucose levels by providing a continuous supply of insulin similar to the pancreas' basal insulin secretion and additional doses to match higher glucose levels during mealtimes, similar to the pancreas' response to food intake. This method aims to improve diabetes control by closely replicating the natural insulin release pattern of a healthy pancreas.
#
# Source:
# https://ch-api.healthhub.sg/api/public/content/0aa3838b8eeb40e6b34a2340a65fdd03?v=eca50be0&_gl=1*1tq2sup*_ga*MTk3Mjg0Mjc5Ni4xNzA3Nzg5OTUw*_ga_VQW1KL2RMR*MTcxMDc1MzAxMS40LjEuMTcxMDc1NDQzMC42MC4wLjA.
# https://www.ace-hta.gov.sg/docs/default-source/acgs/acg-t2dm-personalising-medications.pdf
#
#
# What factors should be considered when determining appropriate exercises for a wheelchair user?
# When determining appropriate exercises for a wheelchair user, factors to consider include:
# 1. Mobility level, such as the ability to transfer in and out of the wheelchair.
# 2. Upper body strength and endurance for activities involving the arms and shoulders.
# 3. Cardiovascular fitness and respiratory function.
# 4. Joint flexibility and range of motion.
# 5. Existing health conditions or injuries that may impact exercise choices.
# 6. Personal preferences and interests to ensure motivation and adherence to the exercise program.
# 7. Accessibility to suitable exercise equipment or facilities for wheelchair users.
#
# Source:
# https://ch-api.healthhub.sg/api/public/content/70e56617c5b140139bb5cb37db3cdef0?v=a7dd48f7&3_gl=1*11zfakr*_ga*MTk3Mjg0Mjc5Ni4xNzA3Nzg5OTUw*_ga_VQW1KL2RMR*MTcxMDc1MzAxMS40LjEuMTcxMDc1NDQzMC42MC4wLjA.
#
#
# What can excess internal fat lead to in terms of inflammation and damage of body cells?
# Excess internal fat, including fat surrounding internal organs and infiltrating organs and muscles, can lead to inflammation and damage of body cells. This can contribute to various health issues such as insulin resistance, high blood pressure, high LDL-cholesterol, low HDL-cholesterol, high triglycerides, and damage to the pancreas and other organs.
#
# Source:
# https://ch-api.healthhub.sg/api/public/content/57349b96ccfe47319fb49d902a064022?v=6a601253&_gl=1*ok09oc*_ga*MTk3Mjg0Mjc5Ni4xNzA3Nzg5OTUw*_ga_VQW1KL2RMR*MTcxMDc1MzAxMS40LjEuMTcxMDc1NDQxNC4xMi4wLjA.
#
#
# What is the suggested location for doing lunchtime exercises?
# The suggested location for doing lunchtime exercises is typically a convenient and accessible area near your workplace. This could be a designated exercise room or space within the office building, a nearby park, a gym close to the workplace, or even a quiet corner in the office if space allows. The key is to find a location that is conducive to physical activity and fits into your schedule during the lunch break.
#
# Source:
# https://ch-api.healthhub.sg/api/public/content/0aa3838b8eeb40e6b34a2340a65fdd03?v=eca50be0&_gl=1*1tq2sup*_ga*MTk3Mjg0Mjc5Ni4xNzA3Nzg5OTUw*_ga_VQW1KL2RMR*MTcxMDc1MzAxMS40LjEuMTcxMDc1NDQzMC42MC4wLjA.
#
#
# What are the main medications used by patients with type 2 diabetes mellitus in Singapore?
# In Singapore, despite the availability of newer classes of medications for type 2 diabetes mellitus (T2DM), metformin and sulphonylureas continue to be the main medications used by patients with T2DM.
#
# Source:
# https://www.ace-hta.gov.sg/docs/default-source/acgs/acg-t2dm-personalising-medications.pdf
#
#
# How can rotating injection sites prevent fat lump formation in insulin pump therapy?
# Rotating injection sites in insulin pump therapy can prevent fat lump formation by ensuring that insulin is injected into different spots each time. Injecting into the same spot repeatedly can lead to the formation of thick areas under the skin known as lipohypertrophy. Insulin injected into these areas may not be absorbed well, leading to uneven insulin delivery and potential complications. By rotating injection sites, you can help prevent these thick areas from forming and ensure proper absorption of insulin.
#
# Source:
# https://www.healthhub.sg/a-z/diseases-and-conditions/diabetes-treatment-insulin
# https://ch-api.healthhub.sg/api/public/content/0aa3838b8eeb40e6b34a2340a65fdd03?v=eca50be0&_gl=1*1tq2sup*_ga*MTk3Mjg0Mjc5Ni4xNzA3Nzg5OTUw*_ga_VQW1KL2RMR*MTcxMDc1MzAxMS40LjEuMTcxMDc1NDQzMC42MC4wLjA.
# https://www.ace-hta.gov.sg/docs/default-source/acgs/acg-t2dm-personalising-medications.pdf
#
#
# What is the purpose of an insulin reservoir in insulin pump therapy and how does it relate to rotating injection sites for proper absorption and to prevent swelling?
# The insulin reservoir in insulin pump therapy serves as a storage container for insulin that is delivered to the body. It holds the insulin that is continuously released as basal insulin and the additional doses of rapid-acting insulin for mealtime boluses.
#
# Rotating injection sites is crucial to prevent swelling and ensure proper absorption of insulin because repeatedly injecting insulin into the same spot can lead to lipohypertrophy, which is the thickening and hardening of fatty tissue under the skin. This condition can affect insulin absorption, causing uneven delivery and potential complications. By rotating injection sites, you can help prevent lipohypertrophy, ensure consistent insulin absorption, and reduce the risk of swelling or other injection site-related issues.
#
# Source:
# https://ch-api.healthhub.sg/api/public/content/0aa3838b8eeb40e6b34a2340a65fdd03?v=eca50be0&_gl=1*1tq2sup*_ga*MTk3Mjg0Mjc5Ni4xNzA3Nzg5OTUw*_ga_VQW1KL2RMR*MTcxMDc1MzAxMS40LjEuMTcxMDc1NDQzMC42MC4wLjA.
# https://www.ace-hta.gov.sg/docs/default-source/acgs/acg-t2dm-personalising-medications.pdf
#
#
# {'question': ['What is gestational diabetes and how is it diagnosed?', 'What are some healthy eating tips for people with diabetes?', 'How can my outpatient bill for diabetes be covered?', 'How does insulin pump therapy mimic the function of the pancreas?', 'What factors should be considered when determining appropriate exercises for a wheelchair user?', 'What can excess internal fat lead to in terms of inflammation and damage of body cells?', 'What is the suggested location for doing lunchtime exercises?', 'What are the main medications used by patients with type 2 diabetes mellitus in Singapore?', 'How can rotating injection sites prevent fat lump formation in insulin pump therapy?', 'What is the purpose of an insulin reservoir in insulin pump therapy and how does it relate to rotating injection sites for proper absorption and to prevent swelling?'], 'source': ['https://www.ace-hta.gov.sg/docs/default-source/acgs/gdm---an-update-on-screening-diagnosis-and-follow-up-(may-2018).pdf\n', 'https://www.ace-hta.gov.sg/docs/default-source/default-library/managing-pre-diabetes-(updated-on-27-jul-2021)c2bfc77474154c2abf623156a4b93002.pdf\n', 'https://ch-api.healthhub.sg/api/public/content/57c95e67895840888240d7322f00117c?v=f00ca9b4&_gl=1*1tq2sup*_ga*MTk3Mjg0Mjc5Ni4xNzA3Nzg5OTUw\n', 'https://ch-api.healthhub.sg/api/public/content/0aa3838b8eeb40e6b34a2340a65fdd03?v=eca50be0&_gl=1*1tq2sup*_ga*MTk3Mjg0Mjc5Ni4xNzA3Nzg5OTUw*_ga_VQW1KL2RMR*MTcxMDc1MzAxMS40LjEuMTcxMDc1NDQzMC42MC4wLjA.\nhttps://www.ace-hta.gov.sg/docs/default-source/acgs/acg-t2dm-personalising-medications.pdf\n', 'https://ch-api.healthhub.sg/api/public/content/70e56617c5b140139bb5cb37db3cdef0?v=a7dd48f7&3_gl=1*11zfakr*_ga*MTk3Mjg0Mjc5Ni4xNzA3Nzg5OTUw*_ga_VQW1KL2RMR*MTcxMDc1MzAxMS40LjEuMTcxMDc1NDQzMC42MC4wLjA.\n', 'https://ch-api.healthhub.sg/api/public/content/57349b96ccfe47319fb49d902a064022?v=6a601253&_gl=1*ok09oc*_ga*MTk3Mjg0Mjc5Ni4xNzA3Nzg5OTUw*_ga_VQW1KL2RMR*MTcxMDc1MzAxMS40LjEuMTcxMDc1NDQxNC4xMi4wLjA.\n', 'https://ch-api.healthhub.sg/api/public/content/0aa3838b8eeb40e6b34a2340a65fdd03?v=eca50be0&_gl=1*1tq2sup*_ga*MTk3Mjg0Mjc5Ni4xNzA3Nzg5OTUw*_ga_VQW1KL2RMR*MTcxMDc1MzAxMS40LjEuMTcxMDc1NDQzMC42MC4wLjA.\n', 'https://www.ace-hta.gov.sg/docs/default-source/acgs/acg-t2dm-personalising-medications.pdf\n', 'https://www.healthhub.sg/a-z/diseases-and-conditions/diabetes-treatment-insulin\nhttps://ch-api.healthhub.sg/api/public/content/0aa3838b8eeb40e6b34a2340a65fdd03?v=eca50be0&_gl=1*1tq2sup*_ga*MTk3Mjg0Mjc5Ni4xNzA3Nzg5OTUw*_ga_VQW1KL2RMR*MTcxMDc1MzAxMS40LjEuMTcxMDc1NDQzMC42MC4wLjA.\nhttps://www.ace-hta.gov.sg/docs/default-source/acgs/acg-t2dm-personalising-medications.pdf\n', 'https://ch-api.healthhub.sg/api/public/content/0aa3838b8eeb40e6b34a2340a65fdd03?v=eca50be0&_gl=1*1tq2sup*_ga*MTk3Mjg0Mjc5Ni4xNzA3Nzg5OTUw*_ga_VQW1KL2RMR*MTcxMDc1MzAxMS40LjEuMTcxMDc1NDQzMC42MC4wLjA.\nhttps://www.ace-hta.gov.sg/docs/default-source/acgs/acg-t2dm-personalising-medications.pdf\n'], 'answer': ['Gestational diabetes is a type of diabetes that develops during pregnancy. It is diagnosed through screening tests such as the 3-point OGTT (oral glucose tolerance test) using the criteria set by the International Association of Diabetes and Pregnancy Study Group (IADPSG), which includes measuring plasma glucose levels at fasting, 1-hour post-OGTT, and 2-hour post-OGTT. If these levels meet the criteria specified in Table 1, then gestational diabetes is diagnosed.', 'Healthy eating tips for people with diabetes include:\n1. Eating a well-balanced diet with a variety of fruits, vegetables, whole grains, lean proteins, and healthy fats.\n2. Monitoring carbohydrate intake and choosing complex carbohydrates over simple sugars.\n3. Limiting saturated fats, trans fats, cholesterol, and sodium in the diet.\n4. Eating regular meals and snacks to help maintain blood sugar levels.\n5. Being mindful of portion sizes and calorie intake to support weight management.\n6. Working with a healthcare provider or dietitian t ...

# %% [markdown]
# LLM evaluation using Retrieval Augmented Generation Assessment (RAGAs)

# %%
from ragas.metrics import (answer_relevancy,faithfulness, context_relevancy)
from ragas import evaluate
from datasets import Dataset

dataset  = Dataset.from_dict(eval_dict)
score = evaluate(dataset,metrics=[faithfulness, answer_relevancy, context_relevancy])
score = score.to_pandas()

display(score)
# Out:
# Evaluating:   0%|          | 0/30 [00:00<?, ?it/s]
#                                             question  \
# 0  What is gestational diabetes and how is it dia...
# 1  What are some healthy eating tips for people w...
# 2  How can my outpatient bill for diabetes be cov...
# 3  How does insulin pump therapy mimic the functi...
# 4  What factors should be considered when determi...
# 5  What can excess internal fat lead to in terms ...
# 6  What is the suggested location for doing lunch...
# 7  What are the main medications used by patients...
# 8  How can rotating injection sites prevent fat l...
# 9  What is the purpose of an insulin reservoir in...
#
#                                               source  \
# 0  https://www.ace-hta.gov.sg/docs/default-source...
# 1  https://www.ace-hta.gov.sg/docs/default-source...
# 2  https://ch-api.healthhub.sg/api/public/content...
# 3  https://ch-api.healthhub.sg/api/public/content...
# 4  https://ch-api.healthhub.sg/api/public/content...
# 5  https://ch-api.healthhub.sg/api/public/content...
# 6  https://ch-api.healthhub.sg/api/public/content...
# 7  https://www.ace-hta.gov.sg/docs/default-source...
# 8  https://www.healthhub.sg/a-z/diseases-and-cond...
# 9  https://ch-api.healthhub.sg/api/public/content...
#
#                                               answer  \
# 0  Gestational diabetes is a type of diabetes tha...
# 1  Healthy eating tips for people with diabetes i...
# 2  Your outpatient bill for diabetes can be cover...
# 3  Insulin pump therapy mimics the function of th...
# 4  When determining appropriate exercises for a w...
# 5  Excess internal fat, including fat surrounding...
# 6  The suggested location for doing lunchtime exe...
# 7  In Singapore, despite the availability of newe...
# 8  Rotating injection sites in insulin pump thera...
# 9  The insulin reservoir in insulin pump therapy ...
#
#                                             contexts  faithfulness  \
# 0  [history of diabetes.1,22\n\nAll women with di...           1.0
# 1  [Healthy diet\n\nA healthy and balanced diet p...           1.0
# 2  [After deduction from the sources above, you m...           1.0
# 3  [medication independent of their effect on HbA...           1.0
# 4  [What exercise are appropriate for me?\n\nWhat...           1.0
# 5  [There may be excess fat in your body even if ...           1.0
# 6  [The table provides reasons for not being able...           1.0
# 7  [More than 95% of people with diabetes have ty...           1.0
# 8  [Rotate your injection spots\n\nRotate injecti...           1.0
# 9  [c Not available as single-ingredient product;...           1.0
#
#    answer_relevancy  context_relevancy
# 0          0.951863           0.388889
# 1          1.000000           0.000000
# 2          0.993797           0.125000
# 3          0.905265           0.050000
# 4          1.000000           0.076923
# 5          0.915512           0.030303
# 6          0.994663           0.250000
# 7          1.000000           0.200000
# 8          0.976867           0.250000
# 9          0.885586           0.200000

# %% [markdown]
# Save Results

# %%
# Faithfulness - Measures the factual consistency of the answer to the context based on the question. i.e., hallucination
# Answer Relevancy - Measures how relevant the answer is to the question

result_df = pd.DataFrame({
    "Reader Query": score["question"].to_list(),
    "Information Retrieved from source": source_list,
    "LLM Response": score["answer"].to_list(),
    "Source Text": score["contexts"],
    "Faithfulness": score["faithfulness"], # measures hallucinations i.e., context -> answer
    "Answer Relevancy": score["answer_relevancy"], # measures answer relevancy i.e., answer -> query
    "Context Relevancy": score["context_relevancy"] # measures context relevancy i.e., query -> context
    })

display(result_df)
# Out:
#                                         Reader Query  \
# 0  What is gestational diabetes and how is it dia...
# 1  What are some healthy eating tips for people w...
# 2  How can my outpatient bill for diabetes be cov...
# 3  How does insulin pump therapy mimic the functi...
# 4  What factors should be considered when determi...
# 5  What can excess internal fat lead to in terms ...
# 6  What is the suggested location for doing lunch...
# 7  What are the main medications used by patients...
# 8  How can rotating injection sites prevent fat l...
# 9  What is the purpose of an insulin reservoir in...
#
#                    Information Retrieved from source  \
# 0  https://www.ace-hta.gov.sg/docs/default-source...
# 1  https://www.ace-hta.gov.sg/docs/default-source...
# 2  https://ch-api.healthhub.sg/api/public/content...
# 3  https://ch-api.healthhub.sg/api/public/content...
# 4  https://ch-api.healthhub.sg/api/public/content...
# 5  https://ch-api.healthhub.sg/api/public/content...
# 6  https://ch-api.healthhub.sg/api/public/content...
# 7  https://www.ace-hta.gov.sg/docs/default-source...
# 8  https://www.healthhub.sg/a-z/diseases-and-cond...
# 9  https://ch-api.healthhub.sg/api/public/content...
#
#                                         LLM Response  \
# 0  Gestational diabetes is a type of diabetes tha...
# 1  Healthy eating tips for people with diabetes i...
# 2  Your outpatient bill for diabetes can be cover...
# 3  Insulin pump therapy mimics the function of th...
# 4  When determining appropriate exercises for a w...
# 5  Excess internal fat, including fat surrounding...
# 6  The suggested location for doing lunchtime exe...
# 7  In Singapore, despite the availability of newe...
# 8  Rotating injection sites in insulin pump thera...
# 9  The insulin reservoir in insulin pump therapy ...
#
#                                          Source Text  Faithfulness  \
# 0  [history of diabetes.1,22\n\nAll women with di...           1.0
# 1  [Healthy diet\n\nA healthy and balanced diet p...           1.0
# 2  [After deduction from the sources above, you m...           1.0
# 3  [medication independent of their effect on HbA...           1.0
# 4  [What exercise are appropriate for me?\n\nWhat...           1.0
# 5  [There may be excess fat in your body even if ...           1.0
# 6  [The table provides reasons for not being able...           1.0
# 7  [More than 95% of people with diabetes have ty...           1.0
# 8  [Rotate your injection spots\n\nRotate injecti...           1.0
# 9  [c Not available as single-ingredient product;...           1.0
#
#    Answer Relevancy  Context Relevancy
# 0          0.951863           0.388889
# 1          1.000000           0.000000
# 2          0.993797           0.125000
# 3          0.905265           0.050000
# 4          1.000000           0.076923
# 5          0.915512           0.030303
# 6          0.994663           0.250000
# 7          1.000000           0.200000
# 8          0.976867           0.250000
# 9          0.885586           0.200000

# %%
result_df.to_csv("Sample Output.csv")
